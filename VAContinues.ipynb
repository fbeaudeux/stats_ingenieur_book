# %% [markdown]
# # SEANCE 3 — Variables aléatoires continues
#
# ## Objectifs de la séance
#
# À l’issue de cette séance, l’étudiant doit être capable de :
# - comprendre la notion de **variable aléatoire continue** ;
# - interpréter une **densité de probabilité** ;
# - utiliser la **loi normale** (centrée réduite et générale) ;
# - appliquer la **règle des 68 %, 95 %, 99,7 %** ;
# - comprendre la **loi exponentielle** et ses usages industriels ;
# - relier modèles probabilistes et phénomènes physiques.
#
# ---
#
# ## 1. Pourquoi des variables aléatoires continues ?
#
# En ingénierie, de nombreuses grandeurs sont **mesurées** et non comptées :
# - température,
# - pression,
# - durée de vie d’un composant,
# - épaisseur d’une pièce,
# - temps d’attente avant une panne.
#
# 👉 Ces grandeurs sont modélisées par des **variables aléatoires continues**.
#
# ---
#
# ## 2. Variable aléatoire continue et densité
#
# ### Définition
#
# Une **variable aléatoire continue** $X$ peut prendre une infinité de valeurs réelles.
#
# On ne calcule pas $P(X=x)$ (qui vaut toujours 0), mais :
#
# $$
# P(a \le X \le b)
# $$
#
# ### Densité de probabilité
#
# La loi de $X$ est décrite par une **densité** $f(x)$ telle que :
# - $f(x)\ge 0$ ;
# - l’aire totale vaut 1 :
# $$
# \int_{-\infty}^{+\infty} f(x)\,dx = 1.
# $$
#
# La probabilité sur un intervalle est :
# $$
# P(a \le X \le b)=\int_a^b f(x)\,dx.
# $$
#
# 👉 Interprétation : une probabilité est une **aire sous une courbe**.
#
# ---
#
# ## 3. Loi normale centrée réduite $N(0;1)$
#
# ### Définition
#
# Une variable $X$ suit une loi normale centrée réduite si :
#
# $$
# f(x)=\frac{1}{\sqrt{2\pi}}\,e^{-x^2/2}, \quad x\in\mathbb{R}.
# $$
#
# ### Propriétés
# - $E(X)=0$ ;
# - $\mathrm{Var}(X)=1$ ;
# - distribution symétrique par rapport à 0.
#
# La loi normale modélise les **erreurs**, les **fluctuations naturelles** et les phénomènes résultant de nombreux effets indépendants.
#
# ---
#
# ## 4. Fonction de répartition et tables
#
# Les tables de la loi normale donnent :
#
# $$
# P(X\le x)
# $$
#
# pour $X\sim N(0;1)$.
#
# On en déduit :
# - $P(X>x)=1-P(X\le x)$ ;
# - $P(a\le X\le b)=P(X\le b)-P(X\le a)$.
#
# Aujourd’hui, ces calculs sont souvent faits par **Python**, mais le raisonnement probabiliste reste essentiel.
#
# ---
#
# ## 5. Loi normale générale $N(\mu;\sigma)$
#
# ### Définition
#
# Une variable $X$ suit une loi normale $N(\mu;\sigma)$ si :
#
# $$
# f(x)=\frac{1}{\sigma\sqrt{2\pi}}
# \exp\!\left(-\frac{(x-\mu)^2}{2\sigma^2}\right).
# $$
#
# - $\mu$ : moyenne (valeur cible),
# - $\sigma$ : écart-type (dispersion).
#
# 👉 En ingénierie :
# - $\mu$ correspond au **réglage nominal** ;
# - $\sigma$ mesure la **variabilité du procédé**.
#
# ---
#
# ## 6. Centrage et réduction
#
# Si $X\sim N(\mu;\sigma)$, alors :
#
# $$
# Z=\frac{X-\mu}{\sigma}
# $$
#
# suit une loi normale centrée réduite $N(0;1)$.
#
# 👉 Cette transformation permet d’utiliser **une seule table** pour toutes les lois normales.
#
# ---
#
# ## 7. Règle des 68 %, 95 %, 99,7 %
#
# Pour $Z\sim N(0;1)$ :
# - $P(-1\le Z\le 1)=0.6826$ ;
# - $P(-2\le Z\le 2)=0.9544$ ;
# - $P(-3\le Z\le 3)=0.9973$.
#
# Donc, pour $X\sim N(\mu;\sigma)$ :
# - $[\mu\pm\sigma]$ contient ≈ 68 % des valeurs ;
# - $[\mu\pm2\sigma]$ contient ≈ 95 % ;
# - $[\mu\pm3\sigma]$ contient ≈ 99,7 %.
#
# 👉 Fondamental en **contrôle qualité**.
#
# ---
#
# ## 8. Exemple industriel (contrôle qualité)
#
# Une résistance a une valeur nominale de 100 Ω et suit une loi $N(100;3)$.
#
# Questions typiques :
# - proportion de pièces conformes à une tolérance ;
# - taux de rebut ;
# - impact d’une réduction de $\sigma$.
#
# ---
#
# ## 9. Loi exponentielle
#
# ### Définition
#
# Une variable $X$ suit une loi exponentielle de paramètre $\lambda>0$ si :
#
# $$
# f(x)=
# \begin{cases}
# 0 & x<0 \\
# \lambda e^{-\lambda x} & x\ge 0
# \end{cases}
# $$
#
# ### Moments
#
# $$
# E(X)=\frac{1}{\lambda}, \qquad \mathrm{Var}(X)=\frac{1}{\lambda^2}.
# $$
#
# ---
#
# ## 10. Propriété de mémoire nulle
#
# $$
# P(X>t+s \mid X>t)=P(X>s).
# $$
#
# 👉 Le passé n’influence pas l’avenir : modèle adapté aux **pannes aléatoires**.
#
# ---
#
# ## 11. Lien avec le théorème central limite
#
# La somme de nombreuses variables indépendantes tend vers une loi normale, même si chaque variable individuelle ne l’est pas.
#
# 👉 La loi normale apparaît comme une **loi universelle**.
#
# ---
#
# ## Conclusion de la séance
#
# - Les variables continues modélisent les phénomènes physiques réels.
# - La loi normale est centrale en statistique appliquée.
# - La loi exponentielle est essentielle en fiabilité et maintenance.
# - Ces notions sont la base des **tests statistiques** et de la **régression linéaire**.

# %% [markdown]
# # TD — Exercices Séance 3 : Variables aléatoires continues
# *(Loi normale et loi exponentielle)*
#
# ---
#
# ## A. Loi normale centrée réduite — $Z \sim \mathcal{N}(0,1)$
#
# ### Exercice A1 — Lecture de table (1)
#
# >Pour la lecture des probabilités associées à la loi normale centrée réduite, vous pouvez consulter la table complète :
#
# > <a href="assets/table-de-la-loi-normale-centree-reduite.pdf" target="_blank">
# 📄 Table de la loi normale $N(0,1)$ (PDF)
# </a>
#
#
# Les valeurs du tableau correspondent à l’aire sous la courbe de la fonction de répartition.
#
#
#
# Soit $Z \sim \mathcal{N}(0,1)$.
#
# 1) Calculer $P(Z \le 1{,}5)$.
# 2) Calculer $P(-0{,}5 \le Z \le 2)$.
# 3) Trouver $z_0$ tel que $P(Z \le z_0)=0{,}95$.
#
# <details>
# <summary>Correction</summary>
#
# 1) À la table :
# $$
# P(Z \le 1{,}5) \approx 0{,}9332
# $$
#
# 2)
# $$
# P(-0{,}5 \le Z \le 2)=P(Z \le 2)-P(Z \le -0{,}5)
# $$
# Avec :
# $$
# P(Z \le 2)\approx 0{,}9772,\quad P(Z \le -0{,}5)\approx 0{,}3085
# $$
# Donc :
# $$
# P(-0{,}5 \le Z \le 2)\approx 0{,}6687
# $$
#
# 3)
# $$
# P(Z \le z_0)=0{,}95 \Rightarrow z_0 \approx 1{,}645
# $$
#
# </details>
#
# ---
#
# ### Exercice A2 — Lecture de table (2)
#
# Soit $Z \sim \mathcal{N}(0,1)$.
#
# 1) Calculer $P(Z \le 0{,}84)$.
# 2) Calculer $P(-1{,}28 \le Z \le 0{,}84)$.
# 3) Déterminer $z_0$ tel que $P(Z \le z_0)=0{,}90$.
#
# <details>
# <summary>Correction</summary>
#
# 1)
# $$
# P(Z \le 0{,}84)\approx 0{,}7995
# $$
#
# 2)
# $$
# P(-1{,}28 \le Z \le 0{,}84)=P(Z \le 0{,}84)-P(Z \le -1{,}28)
# $$
# $$
# \approx 0{,}7995-0{,}1003=0{,}6992
# $$
#
# 3)
# $$
# P(Z \le z_0)=0{,}90 \Rightarrow z_0 \approx 1{,}28
# $$
#
# </details>
#
# ---
#
# ## B. Loi normale générale — $X \sim \mathcal{N}(\mu,\sigma^2)$
#
# ### Exercice B1 — Centrage et réduction
#
# Soit $X\sim\mathcal{N}(100,5^2)$.
#
# 1) Calculer $P(X \le 92)$.
# 2) Calculer $P(95 \le X \le 110)$.
# 3) Déterminer $x_0$ tel que $P(X \le x_0)=0{,}975$.
#
# <details>
# <summary>Correction</summary>
#
# On pose :
# $$
# Z=\frac{X-100}{5}
# $$
#
# 1)
# $$
# Z=\frac{92-100}{5}=-1{,}6
# \Rightarrow P(X\le 92)=P(Z\le -1{,}6)\approx 0{,}0548
# $$
#
# 2)
# $$
# Z_1=-1,\quad Z_2=2
# $$
# $$
# P(95\le X\le 110)=P(-1\le Z\le 2)
# $$
# $$
# \approx 0{,}9772-0{,}1587=0{,}8185
# $$
#
# 3)
# $$
# P(Z\le z_0)=0{,}975 \Rightarrow z_0\approx 1{,}96
# $$
# $$
# x_0=100+1{,}96\times 5=109{,}8
# $$
#
# </details>
#
# ---
#
# ### Exercice B2 — Tailles (exemple classique)
#
# La taille des adultes suit une loi normale de moyenne $170$ cm et d’écart-type $10$ cm.
#
# 1) $P(X<180)$
# 2) $P(160<X<190)$
# 3) Trouver $t_0$ tel que $P(X<t_0)=0{,}90$.
#
# <details>
# <summary>Correction</summary>
#
# On pose :
# $$
# Z=\frac{X-170}{10}
# $$
#
# 1)
# $$
# Z=1 \Rightarrow P(X<180)=0{,}8413
# $$
#
# 2)
# $$
# Z_1=-1,\quad Z_2=2
# $$
# $$
# P(160<X<190)=0{,}9772-0{,}1587=0{,}8185
# $$
#
# 3)
# $$
# z_0\approx 1{,}282
# \Rightarrow t_0=170+1{,}282\times 10\approx 183{,}3\text{ cm}
# $$
#
# </details>
#
# ---
#
# ### Exercice B3 — Contrôle qualité (axes mécaniques)
#
# Le diamètre d’axes mécaniques (en mm) suit $X\sim\mathcal{N}(50,0{,}05^2)$.
# Un axe est conforme si $49{,}9 \le X \le 50{,}1$.
#
# <details>
# <summary>Correction</summary>
#
# On centre-réduit :
# $$
# Z=\frac{X-50}{0{,}05}
# $$
# Bornes :
# $$
# Z_1=-2,\quad Z_2=2
# $$
# Donc :
# $$
# P(49{,}9\le X\le 50{,}1)=P(-2\le Z\le 2)\approx 0{,}9544
# $$
#
# Taux de non-conformité :
# $$
# 1-0{,}9544=0{,}0456 \approx 4{,}6\%
# $$
#
# </details>
#
# ---
#
# ## C. Loi exponentielle — $X \sim \mathcal{E}(\lambda)$
#
# ### Exercice C1 — Durée de vie
#
# La durée de vie d’une machine suit une loi exponentielle de paramètre $\lambda=0{,}2$.
#
# 1) $P(X>5)$
# 2) $P(X<3)$
# 3) Durée de vie moyenne
#
# <details>
# <summary>Correction</summary>
#
# 1)
# $$
# P(X>5)=e^{-0{,}2\times 5}=e^{-1}\approx 0{,}3679
# $$
#
# 2)
# $$
# P(X<3)=1-e^{-0{,}2\times 3}=1-e^{-0{,}6}\approx 0{,}4512
# $$
#
# 3)
# $$
# E(X)=\frac{1}{\lambda}=\frac{1}{0{,}2}=5
# $$
#
# </details>
