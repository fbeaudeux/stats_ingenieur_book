# %% [markdown]
# # Statistiques pratiques pour l’ingénieur
#
# ## Analyse de données, tests statistiques et plan d’expérience
#
# **Parcours Ingénieur de la Conception – S10**
# Génie mécanique
#
# ---
#
# ### Objectifs du livret
#
# Ce document est un support de référence destiné à être utilisé :
# - pendant le stage ingénieur,
# - lors de projets industriels,
# - dans la vie professionnelle.
#
# Il présente :
# - les méthodes statistiques essentielles,
# - des exemples industriels,
# - des outils directement exploitables avec Python.
#
# ---
#
# ### Message clé
#
# > *Les statistiques ne remplacent pas le jugement d’ingénieur :
# > elles l’aident à décider avec rigueur et méthode.*
