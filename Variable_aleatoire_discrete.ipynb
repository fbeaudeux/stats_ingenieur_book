# %% [markdown]
# # SEANCE 2 — Variables aléatoires discrètes
# *Remise à niveau et fondations pour les statistiques inférentielles*
#
# ---
#
# ## Objectifs de la séance
#
# À l’issue de cette séance, l’étudiant doit être capable de :
# - comprendre ce qu’est une **variable aléatoire discrète**,
# - déterminer sa **loi de probabilité**,
# - calculer **espérance, variance et écart-type**,
# - reconnaître et utiliser les **lois discrètes usuelles**,
# - interpréter ces notions dans un **contexte ingénieur**.
#
# ---
#
# ## 1. Pourquoi les variables aléatoires en ingénierie ?
#
# En ingénierie, de nombreux phénomènes sont **incertains** :
# - nombre de défauts sur une série de pièces,
# - nombre de pannes par mois,
# - nombre de succès lors de tests,
# - nombre d’événements rares.
#
# 👉 Une **variable aléatoire (VA)** permet de transformer l’aléa en une **quantité mesurable**.
#
# ---
#
# ## 2. Variable aléatoire discrète
#
# ### Définition
#
# Une **variable aléatoire discrète** $X$ est une fonction qui associe un nombre réel à chaque issue d’une expérience aléatoire :
#
# $$
# X : \Omega \rightarrow \mathbb{R}
# $$
#
# Elle ne peut prendre qu’un **ensemble fini ou dénombrable** de valeurs.
#
# ---
#
# ### Exemple fondamental
#
# On lance **3 fois une pièce équilibrée**.
# On définit $X$ = nombre de piles obtenues.
#
# | Issue | PPP | PPF | PFP | PFF | FPP | FPF | FFP | FFF |
# |---|---|---|---|---|---|---|---|---|
# | $X$ | 3 | 2 | 2 | 1 | 2 | 1 | 1 | 0 |
#
# ---
#
# ## 3. Loi de probabilité
#
# La **loi de probabilité** d’une variable aléatoire est le tableau qui associe :
# - chaque valeur possible $k$,
# - la probabilité $P(X = k)$.
#
# ### Exemple
#
# | $k$ | 0 | 1 | 2 | 3 |
# |---|---|---|---|---|
# | $P(X=k)$ | $1/8$ | $3/8$ | $3/8$ | $1/8$ |
#
# Propriétés :
# - $P(X=k)\ge 0$
# - $\sum_k P(X=k)=1$
#
# ---
#
# ## 4. Fonction de répartition
#
# ### Définition
#
# La **fonction de répartition** de $X$ est définie par :
#
# $$
# F_X(x)=P(X\le x)
# $$
#
# Elle permet de répondre aux questions du type :
# > « Quelle est la probabilité que la variable ne dépasse pas une valeur donnée ? »
#
# ---
#
# ### Exemple
#
# $$
# F_X(x)=
# \begin{cases}
# 0 & x<0 \\
# \frac{1}{8} & 0\le x<1 \\
# \frac{4}{8} & 1\le x<2 \\
# \frac{7}{8} & 2\le x<3 \\
# 1 & x\ge 3
# \end{cases}
# $$
#
# ---
#
# ## 5. Espérance (moyenne théorique)
#
# ### Définition
#
# L’**espérance** d’une variable aléatoire discrète est :
#
# $$
# E(X)=\sum_k k\,P(X=k)
# $$
#
# ### Interprétation
#
# - valeur moyenne obtenue sur un grand nombre de répétitions,
# - **centre de gravité** de la distribution.
#
# ---
#
# ### Exemple
#
# $$
# E(X)=0\times\frac18 + 1\times\frac38 + 2\times\frac38 + 3\times\frac18 = 1.5
# $$
#
# ---
#
# ## 6. Variance et écart-type
#
# ### Définition
#
# La **variance** mesure la dispersion autour de la moyenne :
#
# $$
# \operatorname{Var}(X)=E\left[(X-E(X))^2\right]
# $$
#
# Formule équivalente :
#
# $$
# \operatorname{Var}(X)=E(X^2)-E(X)^2
# $$
#
# L’**écart-type** est :
#
# $$
# \sigma_X=\sqrt{\operatorname{Var}(X)}
# $$
#
# ---
#
# ### Interprétation ingénieur
#
# Deux procédés peuvent avoir la **même moyenne**, mais :
# - l’un très stable,
# - l’autre très dispersé.
#
# 👉 La variance mesure la **variabilité**.
#
# ---
#
# ## 7. Loi de Bernoulli
#
# ### Épreuve de Bernoulli
#
# Expérience à deux issues :
# - succès (probabilité $p$),
# - échec (probabilité $1-p$).
#
# On définit :
#
# $$
# Y=
# \begin{cases}
# 1 & \text{succès} \\
# 0 & \text{échec}
# \end{cases}
# $$
#
# On note : $Y \sim \mathcal{B}(p)$.
#
# ---
#
# ### Propriétés
#
# $$
# E(Y)=p
# $$
#
# $$
# \operatorname{Var}(Y)=p(1-p)
# $$
#
# ---
#
# ## 8. Loi binomiale
#
# ### Schéma de Bernoulli
#
# Répétition de $n$ épreuves de Bernoulli :
# - mêmes conditions,
# - même probabilité $p$,
# - indépendance.
#
# ---
#
# ### Loi binomiale
#
# Soit $X$ le nombre de succès sur $n$ essais :
#
# $$
# X\sim \mathcal{B}(n,p)
# $$
#
# $$
# P(X=k)=\binom{n}{k}p^k(1-p)^{n-k}
# $$
#
# ---
#
# ### Moments
#
# $$
# E(X)=np
# $$
#
# $$
# \operatorname{Var}(X)=np(1-p)
# $$
#
# ---
#
# ## 9. Loi géométrique
#
# ### Définition
#
# On répète des essais de Bernoulli jusqu’au **premier succès**.
#
# $$
# P(X=k)=p(1-p)^{k-1},\quad k\ge1
# $$
#
# ---
#
# ### Propriétés
#
# $$
# E(X)=\frac{1}{p}
# $$
#
# $$
# \operatorname{Var}(X)=\frac{1-p}{p^2}
# $$
#
# ---
#
# ## 10. Loi de Poisson
#
# ### Définition
#
# Utilisée pour modéliser des **événements rares** :
#
# $$
# P(X=k)=e^{-\lambda}\frac{\lambda^k}{k!}
# $$
#
# ---
#
# ### Propriétés
#
# $$
# E(X)=\lambda
# $$
#
# $$
# \operatorname{Var}(X)=\lambda
# $$
#
# ---
#
# ### Approximation binomiale
#
# Si $n$ est grand et $p$ petit, avec $\lambda=np$ :
#
# $$
# \mathcal{B}(n,p)\approx \mathcal{P}(\lambda)
# $$
#
# ---
#
# ## 11. Loi uniforme discrète
#
# ### Définition
#
# Toutes les valeurs sont équiprobables :
#
# $$
# P(X=k)=\frac{1}{n},\quad k=1,\dots,n
# $$
#
# ---
#
# ### Moments
#
# $$
# E(X)=\frac{n+1}{2}
# $$
#
# $$
# \operatorname{Var}(X)=\frac{n^2-1}{12}
# $$
#
# ---
#
# ## 12. À retenir
#
# - Une variable aléatoire modélise un phénomène incertain
# - Espérance = moyenne théorique
# - Variance = dispersion
# - Lois discrètes = modèles fondamentaux
# - Ces notions sont la base des **tests statistiques**

# %% [markdown]
# # TD — Exercices Séance 2 (Variables aléatoires discrètes)
#
#
# ---
#
# ## A. Variables aléatoires discrètes
#
# ### Exercice A1 — Loi donnée (espérance, variance)
#
# ★ Soit $X$ une variable aléatoire dont la loi est donnée par :
# $P(X=-1)=0{,}2$ ; $P(X=0)=0{,}1$ ; $P(X=1)=0{,}4$ ; $P(X=2)=0{,}3$.
#
# 1) Calculer $E(X)$ et $Var(X)$.
# 2) Calculer $P(X \ge 0)$.
#
# <details>
# <summary>Correction</summary>
#
# 1- **Espérance**
#
# $$
# E(X)=\sum x_i P(X=x_i)
# $$
#
# $$
# E(X)=(-1)\cdot 0{,}2 + 0\cdot 0{,}1 + 1\cdot 0{,}4 + 2\cdot 0{,}3
# = -0{,}2 + 0 + 0{,}4 + 0{,}6 = 0{,}8
# $$
#
# **Variance**
#
# $$
# Var(X)=E(X^2)-E(X)^2
# $$
#
# Calcul de $E(X^2)$ :
#
# $$
# E(X^2)=(-1)^2\cdot 0{,}2 + 0^2\cdot 0{,}1 + 1^2\cdot 0{,}4 + 2^2\cdot 0{,}3
# = 0{,}2 + 0 + 0{,}4 + 1{,}2 = 1{,}8
# $$
#
# Donc :
#
# $$
# Var(X)=1{,}8-(0{,}8)^2 = 1{,}8-0{,}64=1{,}16
# $$
#
# 2- **Probabilité $X \ge 0$**
#
# $$
# P(X\ge 0)=P(X=0)+P(X=1)+P(X=2)=0{,}1+0{,}4+0{,}3=0{,}8
# $$
#
# ✅ Résultats : $E(X)=0{,}8$, $Var(X)=1{,}16$, $P(X\ge 0)=0{,}8$.
# </details>
#
# ---
#
# ### Exercice A2 — Dé : variable “carré”
#
# ★ On lance un dé équilibré à 6 faces (1 à 6).
# On note $X$ la variable aléatoire qui associe à chaque lancer **le carré** du numéro obtenu.
#
# 1) Donner la loi de $X$.
# 2) Calculer $E(X)$ et $Var(X)$.
# 3) Calculer $P(X\ge 20)$.
#
# <details>
# <summary> Correction </summary>
#
# **1) Loi de $X$**
#
# Le dé est équilibré donc chaque face a probabilité $1/6$.
#
# Valeurs possibles :
# $$
# X\in\{1,4,9,16,25,36\}
# $$
#
# et
# $$
# P(X=1)=P(X=4)=\cdots=P(X=36)=\frac{1}{6}.
# $$
#
# **2) Espérance**
#
# $$
# E(X)=\frac{1+4+9+16+25+36}{6}=\frac{91}{6}\approx 15{,}17
# $$
#
# **Variance**
#
# $$
# Var(X)=E(X^2)-E(X)^2
# $$
#
# Calcul de $E(X^2)$ :
#
# $$
# E(X^2)=\frac{1^2+4^2+9^2+16^2+25^2+36^2}{6}
# =\frac{1+16+81+256+625+1296}{6}=\frac{2275}{6}
# $$
#
# Donc :
#
# $$
# Var(X)=\frac{2275}{6}-\left(\frac{91}{6}\right)^2
# =\frac{5369}{36}\approx 149{,}14
# $$
#
# **3) Probabilité $X\ge 20$**
#
# Les valeurs $\ge 20$ sont $25$ et $36$.
#
# $$
# P(X\ge 20)=P(X=25)+P(X=36)=\frac{1}{6}+\frac{1}{6}=\frac{1}{3}
# $$
#
# ✅ Résultats : $E(X)\approx 15{,}17$, $Var(X)\approx 149{,}14$, $P(X\ge 20)=1/3$.
# </details>
#
# ---
#
# ## B. Loi binomiale
#
# ### Exercice B1 — Contrôle qualité (ampoules)
#
# ★★ Une usine fabrique des ampoules. On sait que 2 % sont défectueuses.
# On prélève un échantillon de 100 ampoules.
#
# 1) Quelle est la probabilité d’avoir **au plus 3** ampoules défectueuses ?
# 2) Quel est le nombre **moyen** d’ampoules défectueuses ?
# 3) Quelle est la **variance** du nombre d’ampoules défectueuses ?
#
# <details>
#  <summary>Correction</summary>
# Soit $X$ le nombre d’ampoules défectueuses dans 100.
#
# On a un schéma de Bernoulli ($n=100$, $p=0{,}02$), donc :
# $$
# X\sim \mathcal{B}(100,0{,}02)
# $$
#
# **1)**
# $$
# P(X\le 3)=\sum_{k=0}^{3}\binom{100}{k}(0{,}02)^k(0{,}98)^{100-k}\approx 0{,}857
# $$
#
# **2)**
# $$
# E(X)=np=100\times 0{,}02=2
# $$
#
# **3)**
# $$
# Var(X)=np(1-p)=100\times 0{,}02\times 0{,}98=1{,}96
# $$
#
# ✅ Résultats : $P(X\le 3)\approx 0{,}857$, $E(X)=2$, $Var(X)=1{,}96$.
# </details>
#
# ---
#
# ### Exercice B2 — Sites sur une carte (télécom)
#
# ★★ Un ingénieur télécom repère 250 sites potentiels sur une région divisée en 100 carreaux.
# On suppose les sites **uniformes** et **indépendants**.
#
# 1) Pour un carreau donné, quelle est la loi du nombre de sites dans ce carreau ?
# 2) Probabilité de trouver exactement 5 sites ?
# 3) Probabilité d’en trouver plus de 5 ?
#
# <details><summary> Correction </summary>
# Soit $X$ le nombre de sites dans un carreau donné.
#
# Chaque site a probabilité $p=1/100=0{,}01$ d’être dans ce carreau, indépendamment.
#
# Donc :
# $$
# X\sim \mathcal{B}(250,0{,}01)
# $$
#
# **2)**
# $$
# P(X=5)=\binom{250}{5}(0{,}01)^5(0{,}99)^{245}\approx 0{,}066
# $$
#
# **3)**
# $$
# P(X>5)=1-P(X\le 5)
# =1-\sum_{k=0}^{5}\binom{250}{k}(0{,}01)^k(0{,}99)^{250-k}
# \approx 0{,}041
# $$
#
# ✅ Résultats : $P(X=5)\approx 0{,}066$, $P(X>5)\approx 0{,}041$.
# </details>
#
# ---
#
# ### Exercice B3 — Décision d’acceptation d’un lot
#
# ★★★ Une entreprise fabrique des pièces mécaniques. Chaque pièce est défectueuse avec une probabilité constante $p$ (indépendance).
# On prélève $n=20$ pièces et on note $X$ le nombre de pièces défectueuses.
#
# 1) Justifier que $X$ suit une loi binomiale et préciser ses paramètres.
# 2) On accepte le lot si $X\le 2$. Exprimer la probabilité d’acceptation en fonction de $p$.
# 3) Calculer cette probabilité pour $p=0{,}05$ puis $p=0{,}10$.
# 4) Commenter l’influence de $p$ sur la décision.
#
# <details><summary> Correction</summary>
# **1)** Chaque pièce = essai de Bernoulli (défectueuse / non), probabilité $p$, essais indépendants.
#
# Donc :
# $$
# X\sim \mathcal{B}(20,p)
# $$
#
# **2)** Acceptation si $X\le 2$ :
# $$
# P(\text{accept})=P(X\le 2)=\sum_{k=0}^{2}\binom{20}{k}p^k(1-p)^{20-k}
# $$
#
# **3)**
# - Pour $p=0{,}05$ :
# $$
# P(X\le 2)\approx 0{,}924
# $$
# - Pour $p=0{,}10$ :
# $$
# P(X\le 2)\approx 0{,}677
# $$
#
# **4)** Quand $p$ augmente, les défauts sont plus fréquents, donc $P(X\le 2)$ baisse fortement : on rejette plus souvent.
#
# ✅ Résultats : $0{,}924$ (si $p=0{,}05$) vs $0{,}677$ (si $p=0{,}10$).
# </details>
#
# ---
#
# ## C. Loi géométrique
#
# ### Exercice C1 — Première pièce défectueuse
#
# ★★ Une machine produit des pièces avec probabilité d’être défectueuse $p=0{,}1$.
# On teste les pièces une à une jusqu’à obtenir **la première défectueuse**.
# On note $X$ le rang de la première défectueuse (essai de panne inclus).
#
# 1) Probabilité que la première défectueuse soit la 3e ?
# 2) Probabilité qu’elle arrive avant la 5e ?
# 3) Nombre moyen de tests avant la première défectueuse ?
#
# <details><summary> Correction</summary>
# Ici “succès” = “défectueuse”, probabilité $p=0{,}1$.
# Donc :
# $$
# X\sim \mathcal{G}(p)
# $$
# avec
# $$
# P(X=k)=(1-p)^{k-1}p,\quad k\ge 1
# $$
#
# **1)**
# $$
# P(X=3)=(0{,}9)^2\times 0{,}1=0{,}081
# $$
#
# **2)**
# $$
# P(X<5)=P(X=1)+P(X=2)+P(X=3)+P(X=4)
# $$
# Valeur donnée (outil/calcul) :
# $$
# P(X<5)\approx 0{,}3439
# $$
#
# **3)**
# $$
# E(X)=\frac{1}{p}=\frac{1}{0{,}1}=10
# $$
#
# ✅ Résultats : $P(X=3)=0{,}081$, $P(X<5)\approx 0{,}3439$, $E(X)=10$.
# </details>
#
# ---
#
# ### Exercice C2 — Capteur (modèle géométrique)
#
# ★★★ Un capteur fonctionne correctement avec probabilité $p=0{,}98$ à chaque cycle (indépendance). Dès qu’il tombe en panne, il est remplacé.
# On note $X$ le nombre de cycles jusqu’à la première panne (cycle de panne inclus).
#
# 1) Justifier la loi de $X$ et préciser le paramètre.
# 2) Probabilité que la première panne arrive exactement au 50e cycle ?
# 3) Probabilité que le capteur fonctionne au moins 100 cycles ?
# 4) Sachant qu’il a déjà fonctionné 80 cycles sans panne, probabilité de panne au cycle suivant ?
# 5) Interprétation maintenance.
#
# <details><summary>Correction</summary>
# Probabilité de panne à chaque cycle :
# $$
# q=1-p=0{,}02
# $$
# Donc :
# $$
# X\sim \mathcal{G}(q)=\mathcal{G}(0{,}02)
# $$
#
# **2)**
# $$
# P(X=50)=(0{,}98)^{49}\times 0{,}02\approx 0{,}0074
# $$
#
# **3)**
# $$
# P(X\ge 100)=(0{,}98)^{99}\approx 0{,}135
# $$
#
# **4) Propriété de mémoire nulle**
# $$
# P(X=81\mid X>80)=q=0{,}02
# $$
#
# **5) Interprétation**
# Dans ce modèle, le risque de panne instantané reste constant (pas d’effet “vieillissement”).
# </details>
#
# ---
#
# ## D. Loi de Poisson
#
# ### Exercice D1 — Standard téléphonique
#
# ★ Le nombre d’appels reçus par un standard téléphonique suit une loi de Poisson d’espérance 5.
#
# 1) $P(X=3)$
# 2) $P(X\le 2)$
# 3) $P(X\ge 4)$
#
# <details><summary> Correction </summary>
# Ici $X\sim \mathcal{P}(\lambda)$ avec $\lambda=5$ et
# $$
# P(X=k)=e^{-\lambda}\frac{\lambda^k}{k!}
# $$
#
# **1)**
# $$
# P(X=3)=e^{-5}\frac{5^3}{3!}\approx 0{,}140
# $$
#
# **2)**
# $$
# P(X\le 2)=P(0)+P(1)+P(2)\approx 0{,}125
# $$
#
# **3)**
# $$
# P(X\ge 4)=1-P(X\le 3)\approx 0{,}735
# $$
# </details>
#
# ---
#
# ### Exercice D2 — Accidents (Poisson)
#
# ★★ On admet que le nombre d’accidents journaliers sur une autoroute suit une loi de Poisson de paramètre $\lambda=3$.
#
# 1) Calculer $P(X=k)$ pour $k=0,\dots,6$.
# 2) Calculer $P(X\ge 2)$.
# 3) Combien d’accidents en moyenne par jour ?
#
# <details><summary> Correction</summary>
# $X\sim \mathcal{P}(3)$ et
# $$
# P(X=k)=e^{-3}\frac{3^k}{k!}
# $$
#
# **1) Valeurs numériques**
# - $P(X=0)\approx 0{,}0498$
# - $P(X=1)\approx 0{,}1494$
# - $P(X=2)\approx 0{,}2240$
# - $P(X=3)\approx 0{,}2240$
# - $P(X=4)\approx 0{,}1680$
# - $P(X=5)\approx 0{,}1008$
# - $P(X=6)\approx 0{,}0504$
#
# **2)**
# $$
# P(X\ge 2)=1-P(X<2)=1-[P(X=0)+P(X=1)]
# =1-[e^{-3}+3e^{-3}]
# =1-4e^{-3}\approx 0{,}8008
# $$
#
# **3)**
# Pour une Poisson :
# $$
# E(X)=\lambda=3
# $$
# </details>
#
# ---
#
# ### Exercice D3 — Somme de deux Poisson
#
# ★★★ Déterminer la loi de la somme de deux variables aléatoires indépendantes de loi de Poisson de paramètres $\lambda_1$ et $\lambda_2$.
#
# <details><summary> Correction</summary>
# Si $X_1\sim \mathcal{P}(\lambda_1)$ et $X_2\sim \mathcal{P}(\lambda_2)$, indépendantes, alors :
#
# $$
# S=X_1+X_2 \sim \mathcal{P}(\lambda_1+\lambda_2)
# $$
#
# Interprétation : additionner deux “comptages Poisson” indépendants revient à additionner leurs intensités.
# </details>
#
# ---
#
# ### Exercice D4 — Pannes hebdomadaires (maintenance)
#
# ★★★ Dans une usine, le nombre de pannes d’une machine par semaine suit une loi de Poisson de paramètre $\lambda$.
#
# 1) On observe en moyenne 2 pannes/semaine. Donner $\lambda$.
# 2) Probabilité d’aucune panne sur une semaine.
# 3) Probabilité d’au moins 3 pannes sur une semaine.
# 4) Sur 2 semaines : loi et paramètre.
# 5) Probabilité d’exactement 4 pannes sur 2 semaines.
# 6) Interpréter en maintenance préventive.
#
# <details><summary> Correction</summary>
# **1)** Pour une Poisson, $E(X)=\lambda$, donc $\lambda=2$.
#
# **2)**
# $$
# P(X=0)=e^{-2}\approx 0{,}1353
# $$
#
# **3)**
# $$
# P(X\ge 3)=1-[P(0)+P(1)+P(2)]\approx 0{,}3233
# $$
#
# **4)** Sur 2 semaines (somme de deux Poisson indépendantes de paramètre 2) :
# $$
# X_{2\,sem}\sim \mathcal{P}(4)
# $$
#
# **5)**
# $$
# P(X=4)=e^{-4}\frac{4^4}{4!}\approx 0{,}1954
# $$
#
# **6) Interprétation**
# Ces probabilités aident à dimensionner les ressources de maintenance (risque de surcharge), prévoir les pièces de rechange, et estimer la fréquence d’interventions.
# </details>
